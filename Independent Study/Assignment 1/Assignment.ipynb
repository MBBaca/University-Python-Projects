# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pl = pd.read_csv('C:\\Users\\marco\\OneDrive\\Documents\\Fall 2022 Classes\\Indepedent Study\\Assignment1Data.csv')

# %%
pl
# Out:
#                  full_name  age   birthday birthday_GMT          league  \
# 0          Aaron Cresswell   32  629683200   12/15/1989  Premier League
# 1             Aaron Lennon   34  545529600    4/16/1987  Premier League
# 2               Aaron Mooy   31  653356800    9/15/1990  Premier League
# 3             Aaron Ramsey   31  662169600   12/26/1990  Premier League
# 4               Aaron Rowe   21  968284800     9/7/2000  Premier League
# ..                     ...  ...        ...          ...             ...
# 567        Youri Tielemans   24  862963200     5/7/1997  Premier League
# 568          Yves Bissouma   25  841363200    8/30/1996  Premier League
# 569       Zechariah Medley   21  962928000     7/7/2000  Premier League
# 570  Zeze Steven Sessegnon   21  958608000    5/18/2000  Premier League
# 571       Łukasz Fabiański   36  482630400    4/18/1985  Premier League
#
#         season    position            Current Club  minutes_played_overall  \
# ...

# %%
nationality = pl['nationality']

# %%
print(nationality)
# Out:
# 0        England
# 1        England
# 2      Australia
# 3          Wales
# 4        England
#          ...
# 567      Belgium
# 568         Mali
# 569      England
# 570      England
# 571       Poland
# Name: nationality, Length: 572, dtype: object

# %%
nationality.value_counts()
# Out:
# England                217
# Spain                   35
# France                  31
# Belgium                 20
# Republic of Ireland     20
#                       ...
# Israel                   1
# Montenegro               1
# Ecuador                  1
# Iran                     1
# Kenya                    1
# Name: nationality, Length: 67, dtype: int64

# %%
mean_age = pl.groupby('nationality')['age'].mean()
mean_age
# Out:
# nationality
# Algeria      29.500000
# Argentina    32.125000
# Armenia      32.000000
# Australia    30.000000
# Austria      33.750000
#                ...
# USA          28.400000
# Ukraine      28.500000
# Uruguay      30.500000
# Venezuela    28.000000
# Wales        28.666667
# Name: age, Length: 67, dtype: float64

# %%
mean_age['Spain']
# Out:
# 30.65714285714286

# %%
total_goals = pl.groupby('nationality')['goals_overall'].sum()
total_goals
# Out:
# nationality
# Algeria       8
# Argentina    39
# Armenia       6
# Australia     3
# Austria      10
#              ..
# USA           1
# Ukraine       2
# Uruguay       2
# Venezuela    11
# Wales         7
# Name: goals_overall, Length: 67, dtype: int64

# %%
chart = plt.plot(pl['age'], pl['goals_overall'], 'o')
#chart.set_title("Age vs Goals")
#chart.set_xlabel('Age')
#chart.set_ylabel('Goals')
